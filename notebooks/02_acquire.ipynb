# %% [markdown]
# # 3. Populate the Pipeline
#
# This notebook demonstrates how to populate the LC-MS pipeline with simulated data.

# %%
from lcms_demo.pipeline import subject, session, scan
# Out:
# [2026-02-06 02:22:16][WARNING]: SSL connection failed (connection to server at "localhost" (::1), port 5432 failed: server does not support SSL, but SSL was required
# ). Falling back to non-SSL connection. To require SSL, set use_tls=True explicitly.
# [2026-02-06 02:22:16] DataJoint 2.1.0 connected to datajoint@localhost:5432

# %% [markdown]
# ## Option 1: Generic Demo Data
#
# Generate a simple demo dataset with configurable parameters.

# %%
from lcms_demo.simulation import acquire_demo_data

# Step 1: Acquire Manual tables (Subject, Sample, Session)
summary = acquire_demo_data(
    n_subjects=3,
    samples_per_subject=2,
    scans_per_session=50,
    seed=42,
)

print(f"Manual tables acquired:")
print(f"  - {summary['subjects']} subjects")
print(f"  - {summary['samples']} samples")
print(f"  - {summary['sessions']} sessions")
# Out:
# Manual tables acquired:
#   - 3 subjects
#   - 6 samples
#   - 6 sessions

# %%
# Step 2: Populate Imported/Computed tables by calling .populate()
# This triggers the make() methods which read from the data source

scan.Scans.populate(display_progress=True)
scan.Spectra.populate(display_progress=True)
scan.Peaks.populate(display_progress=True)

print("\nPipeline populated!")
# Out:
# Scans:   0%|          | 0/6 [00:00<?, ?it/s]
# Scans:  83%|████████▎ | 5/6 [00:00<00:00, 42.69it/s]
# Scans: 100%|██████████| 6/6 [00:00<00:00, 43.82it/s]
# Spectra:   0%|          | 0/6 [00:00<?, ?it/s]
# Spectra:  50%|█████     | 3/6 [00:00<00:00, 25.50it/s]
# Spectra: 100%|██████████| 6/6 [00:00<00:00, 26.78it/s]
# Spectra: 100%|██████████| 6/6 [00:00<00:00, 26.52it/s]
# Peaks:   0%|          | 0/6 [00:00<?, ?it/s]
# Peaks:  17%|█▋        | 1/6 [00:00<00:03,  1.27it/s]
# Peaks:  50%|█████     | 3/6 [00:00<00:00,  4.04it/s]
# Peaks:  83%|████████▎ | 5/6 [00:01<00:00,  6.67it/s]
# Peaks: 100%|██████████| 6/6 [00:01<00:00,  5.39it/s]
# Pipeline populated!

# %% [markdown]
# ## View Populated Tables

# %%
subject.Subject()
# Out:
# *subject_id    subject_descri
# +------------+ +------------+
# SUBJ_001       Demo subject S
# SUBJ_002       Demo subject S
# SUBJ_003       Demo subject S
#  (Total: 3)

# %%
subject.Sample()
# Out:
# *subject_id    *sample_id     sample_type    collection_dat sample_descrip
# +------------+ +------------+ +------------+ +------------+ +------------+
# SUBJ_001       SAMPLE_001     plasma         2026-02-06 02: Demo sample SA
# SUBJ_001       SAMPLE_002     liver          2026-02-06 02: Demo sample SA
# SUBJ_002       SAMPLE_001     plasma         2026-02-06 02: Demo sample SA
# SUBJ_002       SAMPLE_002     liver          2026-02-06 02: Demo sample SA
# SUBJ_003       SAMPLE_001     plasma         2026-02-06 02: Demo sample SA
# SUBJ_003       SAMPLE_002     liver          2026-02-06 02: Demo sample SA
#  (Total: 6)

# %%
session.Session()
# Out:
# *subject_id    *sample_id     *session_idx   session_dateti instrument_id  method_id     raw_data_path  session_notes
# +------------+ +------------+ +------------+ +------------+ +------------+ +-----------+ +------------+ +------------+
# SUBJ_001       SAMPLE_001     1              2026-02-06 02: QTOF_01        POS_METAB     simulate://42/ Simulated data
# SUBJ_001       SAMPLE_002     1              2026-02-06 02: QTOF_01        POS_METAB     simulate://43/ Simulated data
# SUBJ_002       SAMPLE_001     1              2026-02-06 02: QTOF_01        POS_METAB     simulate://142 Simulated data
# SUBJ_002       SAMPLE_002     1              2026-02-06 02: QTOF_01        POS_METAB     simulate://143 Simulated data
# SUBJ_003       SAMPLE_001     1              2026-02-06 02: QTOF_01        POS_METAB     simulate://242 Simulated data
# SUBJ_003       SAMPLE_002     1              2026-02-06 02: QTOF_01        POS_METAB     simulate://243 Simulated data
#  (Total: 6)

# %%
# View scan data (Part table)
scan.Scans.Scan()
# Out:
# *subject_id    *sample_id     *session_idx   *scan_number   retention_time ms_level     total_ion_curr base_peak_mz   base_peak_inte
# +------------+ +------------+ +------------+ +------------+ +------------+ +----------+ +------------+ +------------+ +------------+
# SUBJ_001       SAMPLE_001     1              1              0.5            1            117122608.0    675.6756591796 1196373.75
# SUBJ_001       SAMPLE_001     1              2              0.734693877551 1            112111464.0    149.5495452880 1232484.375
# SUBJ_001       SAMPLE_001     1              3              0.969387755102 1            82608608.0     153.1531524658 1090651.875
# SUBJ_001       SAMPLE_001     1              4              1.204081632653 1            109376128.0    528.8288574218 1275362.0
# SUBJ_001       SAMPLE_001     1              5              1.438775510204 1            103797952.0    481.0810852050 1610641.25
# SUBJ_001       SAMPLE_001     1              6              1.673469387755 1            152182256.0    637.8378295898 1213865.75
# SUBJ_001       SAMPLE_001     1              7              1.908163265306 1            103510432.0    488.2882995605 1584416.5
# SUBJ_001       SAMPLE_001     1              8              2.142857142857 1            128700872.0    618.9189453125 1687766.25
# SUBJ_001       SAMPLE_001     1              9              2.377551020408 1            92140272.0     280.1801757812 1170666.375
# SUBJ_001       SAMPLE_001     1              10             2.612244897959 1            109687208.0    881.0810546875 2031379.0
# SUBJ_001       SAMPLE_001     1              11             2.846938775510 1            101153464.0    600.0          1552096.125
# SUBJ_001       SAMPLE_001     1              12             3.081632653061 1            122099352.0    236.9369354248 1269745.5
#    ...
#  (Total: 300)

# %% [markdown]
# ## Option 2: NVS-4821 Hepatotoxicity Study
#
# Generate a realistic preclinical study with treatment groups and time-course sampling.
#
# **Note:** Run this in a fresh database or after clearing the demo data.

# %%
# Uncomment to run the hepatotoxicity study simulation

# from lcms_demo.simulation import acquire_nvs4821_study
#
# summary = acquire_nvs4821_study(
#     n_scans_per_session=100,
#     seed=42,
# )
#
# print(f"NVS-4821 Study acquired:")
# print(f"  - {summary['subjects']} subjects")
# print(f"  - {summary['sessions']} sessions")

# %% [markdown]
# ## Manual Data Entry
#
# You can also insert data manually using DataJoint's insert methods.

# %%
# Insert a single subject
subject.Subject.insert1(
    {"subject_id": "MANUAL_001", "subject_description": "Manually entered subject"},
    skip_duplicates=True,
)

subject.Subject()
# Out:
# *subject_id    subject_descri
# +------------+ +------------+
# MANUAL_001     Manually enter
# SUBJ_001       Demo subject S
# SUBJ_002       Demo subject S
# SUBJ_003       Demo subject S
#  (Total: 4)

# %%
# Insert multiple samples
subject.Sample.insert(
    [
        {"subject_id": "MANUAL_001", "sample_id": "plasma_01", "sample_type": "plasma"},
        {"subject_id": "MANUAL_001", "sample_id": "liver_01", "sample_type": "liver"},
    ],
    skip_duplicates=True,
)

subject.Sample()
# Out:
# *subject_id    *sample_id     sample_type    collection_dat sample_descrip
# +------------+ +------------+ +------------+ +------------+ +------------+
# MANUAL_001     liver_01       liver          None
# MANUAL_001     plasma_01      plasma         None
# SUBJ_001       SAMPLE_001     plasma         2026-02-06 02: Demo sample SA
# SUBJ_001       SAMPLE_002     liver          2026-02-06 02: Demo sample SA
# SUBJ_002       SAMPLE_001     plasma         2026-02-06 02: Demo sample SA
# SUBJ_002       SAMPLE_002     liver          2026-02-06 02: Demo sample SA
# SUBJ_003       SAMPLE_001     plasma         2026-02-06 02: Demo sample SA
# SUBJ_003       SAMPLE_002     liver          2026-02-06 02: Demo sample SA
#  (Total: 8)
