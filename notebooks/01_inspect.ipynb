# %% [markdown]
# # 1. Inspect the Pipeline
#
# This notebook shows the LC-MS pipeline structure and current data.

# %%
import datajoint as dj
from lcms_demo.pipeline import subject, session, scan
# Out:
# [2026-02-06 10:26:17][WARNING]: SSL connection failed (connection to server at "localhost" (::1), port 5432 failed: server does not support SSL, but SSL was required
# ). Falling back to non-SSL connection. To require SSL, set use_tls=True explicitly.
# [2026-02-06 10:26:17] DataJoint 2.1.0 connected to datajoint@localhost:5432

# %% [markdown]
# ## Pipeline Diagram
#
# **Legend:**
# - **Green**: Manual tables (data entered directly)
# - **Gray**: Lookup tables (reference data)
# - **Blue**: Imported tables (data from external sources)
# - **Red**: Computed tables (derived data)
# - **Solid lines**: Primary key dependencies
# - **Dashed lines**: Non-primary foreign keys

# %%
dj.Diagram(subject.schema) + dj.Diagram(session.schema) + dj.Diagram(scan.schema)

# %% [markdown]
# ## Current Data

# %%
subject.Subject()
# Out:
# *subject_id    subject_descri
# +------------+ +------------+
#
#  (Total: 0)

# %%
subject.Sample()
# Out:
# *subject_id    *sample_id    sample_type    collection_dat sample_descrip
# +------------+ +-----------+ +------------+ +------------+ +------------+
#
#  (Total: 0)

# %%
session.Session()
# Out:
# *subject_id    *sample_id    *session_idx   session_dateti instrument_id  method_id     raw_data_path  session_notes
# +------------+ +-----------+ +------------+ +------------+ +------------+ +-----------+ +------------+ +------------+
#
#  (Total: 0)

# %%
scan.Scans()
# Out:
# *subject_id    *sample_id    *session_idx   n_scans
# +------------+ +-----------+ +------------+ +---------+
#
#  (Total: 0)

# %%
scan.Scans.Scan()
# Out:
# *subject_id    *sample_id    *session_idx   *scan_number   retention_time ms_level     total_ion_curr base_peak_mz   base_peak_inte
# +------------+ +-----------+ +------------+ +------------+ +------------+ +----------+ +------------+ +------------+ +------------+
#
#  (Total: 0)
