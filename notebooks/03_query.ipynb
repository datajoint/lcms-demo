# %% [markdown]
# # 4. Query and Visualize Data
#
# This notebook demonstrates DataJoint query operations and data visualization for the LC-MS pipeline.

# %%
import numpy as np
import matplotlib.pyplot as plt

from lcms_demo.pipeline import subject, session, scan
# Out:
# [2026-02-06 11:30:26][WARNING]: SSL connection failed (connection to server at "localhost" (::1), port 5432 failed: server does not support SSL, but SSL was required
# ). Falling back to non-SSL connection. To require SSL, set use_tls=True explicitly.
# [2026-02-06 11:30:26] DataJoint 2.1.0 connected to datajoint@localhost:5432

# %% [markdown]
# ## Basic Queries
#
# ### Fetch All Data

# %%
# View subjects table
subject.Subject()
# Out:
# *subject_id    subject_descri
# +------------+ +------------+
# RAT_001        Group 1: Vehic
# RAT_002        Group 1: Vehic
# RAT_003        Group 1: Vehic
# RAT_004        Group 1: Vehic
# RAT_005        Group 1: Vehic
# RAT_006        Group 1: Vehic
# RAT_007        Group 1: Vehic
# RAT_008        Group 1: Vehic
# RAT_009        Group 2: NVS48
# RAT_010        Group 2: NVS48
# RAT_011        Group 2: NVS48
# RAT_012        Group 2: NVS48
#    ...
#  (Total: 59)

# %%
# Fetch all subjects as a pandas DataFrame
subjects_df = subject.Subject.to_pandas()
subjects_df
# Out:
#                                    subject_description
# subject_id
# SUBJ_001                         Demo subject SUBJ_001
# SUBJ_002                         Demo subject SUBJ_002
# SUBJ_003                         Demo subject SUBJ_003
# RAT_001                      Group 1: Vehicle, 0 mg/kg
# RAT_002                      Group 1: Vehicle, 0 mg/kg
# RAT_003                      Group 1: Vehicle, 0 mg/kg
# RAT_004                      Group 1: Vehicle, 0 mg/kg
# RAT_005                      Group 1: Vehicle, 0 mg/kg
# RAT_006                      Group 1: Vehicle, 0 mg/kg
# RAT_007                      Group 1: Vehicle, 0 mg/kg
# RAT_008                      Group 1: Vehicle, 0 mg/kg
# RAT_009                 Group 2: NVS4821_Low, 30 mg/kg
# RAT_010                 Group 2: NVS4821_Low, 30 mg/kg
# RAT_011                 Group 2: NVS4821_Low, 30 mg/kg
# RAT_012                 Group 2: NVS4821_Low, 30 mg/kg
# RAT_013                 Group 2: NVS4821_Low, 30 mg/kg
# RAT_014                 Group 2: NVS4821_Low, 30 mg/kg
# RAT_015                 Group 2: NVS4821_Low, 30 mg/kg
# RAT_016                 Group 2: NVS4821_Low, 30 mg/kg
# RAT_017                Group 3: NVS4821_Mid, 100 mg/kg
# RAT_018                Group 3: NVS4821_Mid, 100 mg/kg
# RAT_019                Group 3: NVS4821_Mid, 100 mg/kg
# RAT_020                Group 3: NVS4821_Mid, 100 mg/kg
# RAT_021                Group 3: NVS4821_Mid, 100 mg/kg
# RAT_022                Group 3: NVS4821_Mid, 100 mg/kg
# RAT_023                Group 3: NVS4821_Mid, 100 mg/kg
# RAT_024                Group 3: NVS4821_Mid, 100 mg/kg
# RAT_025               Group 4: NVS4821_High, 300 mg/kg
# RAT_026               Group 4: NVS4821_High, 300 mg/kg
# RAT_027               Group 4: NVS4821_High, 300 mg/kg
# RAT_028               Group 4: NVS4821_High, 300 mg/kg
# RAT_029               Group 4: NVS4821_High, 300 mg/kg
# RAT_030               Group 4: NVS4821_High, 300 mg/kg
# RAT_031               Group 4: NVS4821_High, 300 mg/kg
# RAT_032               Group 4: NVS4821_High, 300 mg/kg
# RAT_033            Group 5: Vehicle_Satellite, 0 mg/kg
# RAT_034            Group 5: Vehicle_Satellite, 0 mg/kg
# RAT_035            Group 5: Vehicle_Satellite, 0 mg/kg
# RAT_036            Group 5: Vehicle_Satellite, 0 mg/kg
# RAT_037            Group 5: Vehicle_Satellite, 0 mg/kg
# RAT_038            Group 5: Vehicle_Satellite, 0 mg/kg
# RAT_039            Group 5: Vehicle_Satellite, 0 mg/kg
# RAT_040            Group 5: Vehicle_Satellite, 0 mg/kg
# RAT_041            Group 5: Vehicle_Satellite, 0 mg/kg
# RAT_042            Group 5: Vehicle_Satellite, 0 mg/kg
# RAT_043            Group 5: Vehicle_Satellite, 0 mg/kg
# RAT_044            Group 5: Vehicle_Satellite, 0 mg/kg
# RAT_045     Group 6: NVS4821_High_Satellite, 300 mg/kg
# RAT_046     Group 6: NVS4821_High_Satellite, 300 mg/kg
# RAT_047     Group 6: NVS4821_High_Satellite, 300 mg/kg
# RAT_048     Group 6: NVS4821_High_Satellite, 300 mg/kg
# RAT_049     Group 6: NVS4821_High_Satellite, 300 mg/kg
# RAT_050     Group 6: NVS4821_High_Satellite, 300 mg/kg
# RAT_051     Group 6: NVS4821_High_Satellite, 300 mg/kg
# RAT_052     Group 6: NVS4821_High_Satellite, 300 mg/kg
# RAT_053     Group 6: NVS4821_High_Satellite, 300 mg/kg
# RAT_054     Group 6: NVS4821_High_Satellite, 300 mg/kg
# RAT_055     Group 6: NVS4821_High_Satellite, 300 mg/kg
# RAT_056     Group 6: NVS4821_High_Satellite, 300 mg/kg

# %% [markdown]
# ### Restriction (Filtering)

# %%
# Filter samples by type
subject.Sample & "sample_type = 'plasma'"
# Out:
# *subject_id    *sample_id     sample_type    collection_dat sample_descrip
# +------------+ +------------+ +------------+ +------------+ +------------+
# RAT_001        PLASMA_D15     plasma         2026-01-16 00: Day 15 plasma
# RAT_002        PLASMA_D15     plasma         2026-01-16 00: Day 15 plasma
# RAT_003        PLASMA_D15     plasma         2026-01-16 00: Day 15 plasma
# RAT_004        PLASMA_D15     plasma         2026-01-16 00: Day 15 plasma
# RAT_005        PLASMA_D15     plasma         2026-01-16 00: Day 15 plasma
# RAT_006        PLASMA_D15     plasma         2026-01-16 00: Day 15 plasma
# RAT_007        PLASMA_D15     plasma         2026-01-16 00: Day 15 plasma
# RAT_008        PLASMA_D15     plasma         2026-01-16 00: Day 15 plasma
# RAT_009        PLASMA_D15     plasma         2026-01-16 00: Day 15 plasma
# RAT_010        PLASMA_D15     plasma         2026-01-16 00: Day 15 plasma
# RAT_011        PLASMA_D15     plasma         2026-01-16 00: Day 15 plasma
# RAT_012        PLASMA_D15     plasma         2026-01-16 00: Day 15 plasma
#    ...
#  (Total: 107)

# %%
# Filter scans by retention time window
scan.Acquisition.Scan & "retention_time BETWEEN 5 AND 10"
# Out:
# *subject_id    *sample_id    *session_idx   *scan_number   retention_time ms_level     total_ion_curr base_peak_mz   base_peak_inte
# +------------+ +-----------+ +------------+ +------------+ +------------+ +----------+ +------------+ +------------+ +------------+
# RAT_001        LIVER_D15     1              21             5.193877551020 1            112184912.0    462.1621704101 1362177.625
# RAT_001        LIVER_D15     1              22             5.428571428571 1            126265664.0    335.1351318359 1631360.875
# RAT_001        LIVER_D15     1              23             5.663265306122 1            98952608.0     563.9639892578 966746.0
# RAT_001        LIVER_D15     1              24             5.897959183673 1            128716304.0    731.5315551757 1387344.0
# RAT_001        LIVER_D15     1              25             6.132653061224 1            99244320.0     753.1531372070 1059814.25
# RAT_001        LIVER_D15     1              26             6.367346938775 1            132530568.0    283.7837829589 1973349.5
# RAT_001        LIVER_D15     1              27             6.602040816326 1            103405928.0    338.7387390136 1347720.5
# RAT_001        LIVER_D15     1              28             6.836734693877 1            121427840.0    346.8468322753 1030426.5
# RAT_001        LIVER_D15     1              29             7.071428571428 1            107960696.0    664.8648681640 1719528.625
# RAT_001        LIVER_D15     1              30             7.306122448979 1            105611552.0    490.9909973144 1461002.0
# RAT_001        LIVER_D15     1              31             7.540816326530 1            90882160.0     865.7657470703 1602604.0
# RAT_001        LIVER_D15     1              32             7.775510204081 1            148394096.0    945.0450439453 1031453.375
#    ...
#  (Total: 8988)

# %% [markdown]
# ### Projection (Selecting Columns)

# %%
# Select and rename attributes
scan.Acquisition.Scan.proj(rt="retention_time", tic="total_ion_current")
# Out:
# *subject_id    *sample_id    *session_idx   *scan_number   rt             tic
# +------------+ +-----------+ +------------+ +------------+ +------------+ +------------+
# RAT_001        LIVER_D15     1              1              0.5            86824208.0
# RAT_001        LIVER_D15     1              2              0.734693877551 138760608.0
# RAT_001        LIVER_D15     1              3              0.969387755102 126724656.0
# RAT_001        LIVER_D15     1              4              1.204081632653 103397288.0
# RAT_001        LIVER_D15     1              5              1.438775510204 100511048.0
# RAT_001        LIVER_D15     1              6              1.673469387755 104764752.0
# RAT_001        LIVER_D15     1              7              1.908163265306 98596088.0
# RAT_001        LIVER_D15     1              8              2.142857142857 118808672.0
# RAT_001        LIVER_D15     1              9              2.377551020408 94729592.0
# RAT_001        LIVER_D15     1              10             2.612244897959 124546064.0
# RAT_001        LIVER_D15     1              11             2.846938775510 97923152.0
# RAT_001        LIVER_D15     1              12             3.081632653061 111654912.0
#    ...
#  (Total: 21400)

# %% [markdown]
# ### Join Operations

# %%
# Join tables to get combined information
subject.Subject * subject.Sample
# Out:
# *subject_id    *sample_id     sample_type    collection_dat sample_descrip subject_descri
# +------------+ +------------+ +------------+ +------------+ +------------+ +------------+
# RAT_001        LIVER_D15      liver          2026-01-16 00: Day 15 liver s Group 1: Vehic
# RAT_001        PLASMA_D15     plasma         2026-01-16 00: Day 15 plasma  Group 1: Vehic
# RAT_002        LIVER_D15      liver          2026-01-16 00: Day 15 liver s Group 1: Vehic
# RAT_002        PLASMA_D15     plasma         2026-01-16 00: Day 15 plasma  Group 1: Vehic
# RAT_003        LIVER_D15      liver          2026-01-16 00: Day 15 liver s Group 1: Vehic
# RAT_003        PLASMA_D15     plasma         2026-01-16 00: Day 15 plasma  Group 1: Vehic
# RAT_004        LIVER_D15      liver          2026-01-16 00: Day 15 liver s Group 1: Vehic
# RAT_004        PLASMA_D15     plasma         2026-01-16 00: Day 15 plasma  Group 1: Vehic
# RAT_005        LIVER_D15      liver          2026-01-16 00: Day 15 liver s Group 1: Vehic
# RAT_005        PLASMA_D15     plasma         2026-01-16 00: Day 15 plasma  Group 1: Vehic
# RAT_006        LIVER_D15      liver          2026-01-16 00: Day 15 liver s Group 1: Vehic
# RAT_006        PLASMA_D15     plasma         2026-01-16 00: Day 15 plasma  Group 1: Vehic
#    ...
#  (Total: 214)

# %% [markdown]
# ### Aggregation

# %%
# Count scans per session
session.Session.aggr(scan.Acquisition.Scan, n_scans="count(scan_number)")
# Out:
# *subject_id    *sample_id     *session_idx   n_scans
# +------------+ +------------+ +------------+ +---------+
# RAT_001        LIVER_D15      1              50
# RAT_001        LIVER_D15      2              50
# RAT_001        PLASMA_D15     1              50
# RAT_001        PLASMA_D15     2              50
# RAT_002        LIVER_D15      1              50
# RAT_002        LIVER_D15      2              50
# RAT_002        PLASMA_D15     1              50
# RAT_002        PLASMA_D15     2              50
# RAT_003        LIVER_D15      1              50
# RAT_003        LIVER_D15      2              50
# RAT_003        PLASMA_D15     1              50
# RAT_003        PLASMA_D15     2              50
#    ...
#  (Total: 428)

# %% [markdown]
# ---
#
# ## Data Visualization
#
# ### Total Ion Chromatogram (TIC)
#
# The TIC shows the total ion current as a function of retention time.

# %%
# Get the first session
first_session_query = session.Session & {'subject_id': 'SUBJ_001', 'sample_id': 'SAMPLE_001'}
first_session = first_session_query.to_dicts()[0]
print(f"Session: {first_session['subject_id']} / {first_session['sample_id']}")

# Fetch scan data from Part table (reset_index to include PK columns)
scans_df = (scan.Acquisition.Scan & first_session_query).to_pandas().reset_index()
scans_df = scans_df.sort_values('scan_number').reset_index(drop=True)

scans_df.head()
# Out:
# Session: SUBJ_001 / SAMPLE_001
#   subject_id   sample_id  session_idx  scan_number  retention_time  ms_level  \
# 0   SUBJ_001  SAMPLE_001            1            1        0.500000         1
# 1   SUBJ_001  SAMPLE_001            2            1        0.500000         1
# 2   SUBJ_001  SAMPLE_001            1            2        0.734694         1
# 3   SUBJ_001  SAMPLE_001            2            2        0.734694         1
# 4   SUBJ_001  SAMPLE_001            1            3        0.969388         1
#
#    total_ion_current  base_peak_mz  base_peak_intensity
# 0        117122608.0    675.675659          1196373.750
# 1        117122608.0    675.675659          1196373.750
# 2        112111464.0    149.549545          1232484.375
# 3        112111464.0    149.549545          1232484.375
# 4         82608608.0    153.153152          1090651.875

# %%
fig, ax = plt.subplots(figsize=(10, 4))

ax.plot(scans_df['retention_time'], scans_df['total_ion_current'], 'b-', linewidth=0.8)
ax.fill_between(scans_df['retention_time'], scans_df['total_ion_current'], alpha=0.3)

ax.set_xlabel('Retention Time (min)')
ax.set_ylabel('Total Ion Current')
ax.set_title(f"Total Ion Chromatogram - {first_session['subject_id']} / {first_session['sample_id']}")
ax.ticklabel_format(style='scientific', axis='y', scilimits=(0,0))

plt.tight_layout()

# %% [markdown]
# ### Base Peak Chromatogram (BPC)
#
# The BPC shows the intensity of the most intense peak at each scan.

# %%
fig, axes = plt.subplots(2, 1, figsize=(10, 6), sharex=True)

# Base peak intensity
axes[0].plot(scans_df['retention_time'], scans_df['base_peak_intensity'], 'g-', linewidth=0.8)
axes[0].fill_between(scans_df['retention_time'], scans_df['base_peak_intensity'], alpha=0.3, color='green')
axes[0].set_ylabel('Base Peak Intensity')
axes[0].set_title('Base Peak Chromatogram')
axes[0].ticklabel_format(style='scientific', axis='y', scilimits=(0,0))

# Base peak m/z
axes[1].scatter(scans_df['retention_time'], scans_df['base_peak_mz'], s=2, alpha=0.5, c='purple')
axes[1].set_xlabel('Retention Time (min)')
axes[1].set_ylabel('Base Peak m/z')
axes[1].set_title('Base Peak m/z vs Retention Time')

plt.tight_layout()

# %% [markdown]
# ### Mass Spectrum
#
# Display a single mass spectrum from the dataset.

# %%
# Get spectrum for scan at peak TIC
peak_idx = scans_df['total_ion_current'].idxmax()
peak_scan = scans_df.iloc[peak_idx]

# Get spectrum from Part table (use same session restriction)
spectrum_query = (
    scan.MassAnalysis.Spectrum 
    & first_session_query 
    & {'scan_number': int(peak_scan['scan_number'])}
)
spectrum = spectrum_query.to_dicts()[0]
print(f"Spectrum at RT = {peak_scan['retention_time']:.2f} min (scan #{peak_scan['scan_number']})")
# Out:
# Spectrum at RT = 1.67 min (scan #6)

# %%
fig, ax = plt.subplots(figsize=(10, 4))

mz = spectrum['mz_array']
intensity = spectrum['intensity_array']

# Plot as stem plot for mass spectrum
ax.vlines(mz, 0, intensity, linewidth=0.5, color='blue')

ax.set_xlabel('m/z')
ax.set_ylabel('Intensity')
ax.set_title(f"Mass Spectrum at RT = {peak_scan['retention_time']:.2f} min")
ax.ticklabel_format(style='scientific', axis='y', scilimits=(0,0))

plt.tight_layout()

# %% [markdown]
# ### Zoomed Spectrum Region

# %%
# Zoom into a region around the base peak
base_peak_mz = mz[np.argmax(intensity)]
window = 50  # +/- 50 Da

mask = (mz >= base_peak_mz - window) & (mz <= base_peak_mz + window)

fig, ax = plt.subplots(figsize=(10, 4))

ax.vlines(mz[mask], 0, intensity[mask], linewidth=1, color='blue')

ax.set_xlabel('m/z')
ax.set_ylabel('Intensity')
ax.set_title(f"Mass Spectrum (m/z {base_peak_mz-window:.0f} - {base_peak_mz+window:.0f})")
ax.ticklabel_format(style='scientific', axis='y', scilimits=(0,0))

plt.tight_layout()

# %% [markdown]
# ### Detected Peaks
#
# Visualize the peaks detected by the Peaks computed table.

# %%
# Check if peaks have been computed for this session
peaks_query = scan.PeakDetection & first_session_query

if peaks_query:
    peak_data = peaks_query.to_dicts()[0]
    total_peaks = peak_data['total_peaks']
    
    # Get individual peaks for the specific scan
    scan_peaks = (
        scan.PeakDetection.Peak 
        & first_session_query 
        & {'scan_number': int(peak_scan['scan_number'])}
    ).to_pandas().reset_index(drop=True)
    
    print(f"Detected {len(scan_peaks)} peaks in scan #{int(peak_scan['scan_number'])}")
    print(f"Total peaks in session: {total_peaks}")
    display(scan_peaks.head(10))
else:
    print("No peaks detected yet. Run PeakDetection.populate() to detect peaks.")
    scan_peaks = None
# Out:
# Detected 162 peaks in scan #6
# Total peaks in session: 1289
#            mz     intensity        snr
# 0  151.351349  4.354833e+05  36.434715
# 1  161.261261  4.695738e+05  39.286900
# 2  218.918915  3.998138e+05  33.450428
# 3  277.477478  9.218464e+05  77.126297
# 4  294.594604  8.518846e+05  71.272942
# 5  338.738739  3.809836e+05  31.875002
# 6  379.279266  1.115508e+06  93.328995
# 7  387.387390  5.259686e+05  44.005173
# 8  408.108093  5.170425e+05  43.258366
# 9  434.234222  6.784536e+05  56.762829

# %%
if scan_peaks is not None and len(scan_peaks) > 0:
    fig, ax = plt.subplots(figsize=(10, 4))
    
    # Plot full spectrum
    ax.vlines(mz, 0, intensity, linewidth=0.3, color='gray', alpha=0.5)
    
    # Overlay detected peaks
    ax.vlines(scan_peaks['mz'], 0, scan_peaks['intensity'], linewidth=1, color='red', label='Detected peaks')
    ax.scatter(scan_peaks['mz'], scan_peaks['intensity'], s=10, color='red', zorder=5)
    
    ax.set_xlabel('m/z')
    ax.set_ylabel('Intensity')
    ax.set_title(f"Detected Peaks ({len(scan_peaks)} peaks)")
    ax.ticklabel_format(style='scientific', axis='y', scilimits=(0,0))
    ax.legend()
    
    plt.tight_layout()

# %% [markdown]
# ### Peak Statistics

# %%
if scan_peaks is not None and len(scan_peaks) > 0:
    fig, axes = plt.subplots(1, 2, figsize=(10, 4))
    
    # SNR distribution
    axes[0].hist(scan_peaks['snr'], bins=30, edgecolor='black', alpha=0.7)
    axes[0].set_xlabel('Signal-to-Noise Ratio')
    axes[0].set_ylabel('Count')
    axes[0].set_title('Peak SNR Distribution')
    axes[0].axvline(scan_peaks['snr'].median(), color='red', linestyle='--', label=f"Median: {scan_peaks['snr'].median():.1f}")
    axes[0].legend()
    
    # m/z vs intensity
    scatter = axes[1].scatter(scan_peaks['mz'], scan_peaks['intensity'], c=scan_peaks['snr'], s=10, cmap='viridis', alpha=0.7)
    axes[1].set_xlabel('m/z')
    axes[1].set_ylabel('Intensity')
    axes[1].set_title('Peak Intensity vs m/z')
    axes[1].ticklabel_format(style='scientific', axis='y', scilimits=(0,0))
    plt.colorbar(scatter, ax=axes[1], label='SNR')
    
    plt.tight_layout()

# %% [markdown]
# ## Summary Statistics

# %%
print("Pipeline Summary")
print("=" * 40)
print(f"Subjects:            {len(subject.Subject()):>6}")
print(f"Samples:             {len(subject.Sample()):>6}")
print(f"Sessions:            {len(session.Session()):>6}")
print(f"Acquisition:         {len(scan.Acquisition()):>6}")
print(f"  - Scan:            {len(scan.Acquisition.Scan()):>6}")
print(f"MassAnalysis:        {len(scan.MassAnalysis()):>6}")
print(f"  - Spectrum:        {len(scan.MassAnalysis.Spectrum()):>6}")
print(f"PeakDetectionParams: {len(scan.PeakDetectionParams()):>6}")
print(f"PeakDetection:       {len(scan.PeakDetection()):>6}")
print(f"  - Peak:            {len(scan.PeakDetection.Peak()):>6}")
# Out:
# Pipeline Summary
# ========================================
# Subjects:                59
# Samples:                214
# Sessions:               428
# Acquisition:            428
#   - Scan:             21400
# MassAnalysis:           428
#   - Spectrum:         21400
# PeakDetectionParams:      3
# PeakDetection:         1284
#   - Peak:            1668769
